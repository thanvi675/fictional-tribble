# %% [markdown]
# <a href="https://colab.research.google.com/github/thanvi675/fictional-tribble/blob/main/iris_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris


iris = load_iris()


df = pd.DataFrame(iris.data, columns=iris.feature_names)

print("IRIS Dataset:")
print(df)


print("\n--- Measures of Central Tendency ---")


print("\nMean:")
print(df.mean())


print("\nMedian:")
print(df.median())


print("\nMode:")
print(df.mode().iloc[0])




print("\n--- Measures of Dispersion ---")


print("\nRange:")
print(df.max() - df.min())


print("\nVariance:")
print(df.var())


print("\nStandard Deviation:")
print(df.std())
# Out:
# IRIS Dataset:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...
