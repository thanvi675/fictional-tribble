# %% [markdown]
# <a href="https://colab.research.google.com/github/thanvi675/fictional-tribble/blob/main/data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# --------------------------------------------------
# 1. Load the dataset
# --------------------------------------------------

data = pd.read_csv("Titanic.csv")

print("Original Dataset")
print(data.head())

# --------------------------------------------------
# 2. Dataset inspection
# --------------------------------------------------

print("\nNumber of Rows and Columns:")
print(data.shape)

print("\nColumn Information:")
data.info()

print("\nStatistical Summary:")
print(data.describe())

# --------------------------------------------------
# 3. Find missing values
# --------------------------------------------------

print("\nNull Values:")
print(data.isnull().sum())

# --------------------------------------------------
# 4. Handle missing values
# --------------------------------------------------

data["Age"] = data["Age"].fillna(data["Age"].median())

data["Fare"] = data["Fare"].fillna(data["Fare"].median())

data["Embarked"] = data["Embarked"].fillna(
    data["Embarked"].value_counts().index[0]
)

# --------------------------------------------------
# 5. Remove unnecessary column
# --------------------------------------------------

if "Cabin" in data.columns:
    data.drop("Cabin", axis=1, inplace=True)

# --------------------------------------------------
# 6. Remove duplicate rows
# --------------------------------------------------

data = data.drop_duplicates()

# --------------------------------------------------
# 7. Outlier treatment using IQR
# --------------------------------------------------

Q1 = data["Fare"].quantile(0.25)
Q3 = data["Fare"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

data = data[
    (data["Fare"] >= lower_limit) &
    (data["Fare"] <= upper_limit)
]

# --------------------------------------------------
# 8. One-hot encoding
# --------------------------------------------------

data = pd.get_dummies(
    data,
    columns=["Sex", "Embarked"],
    drop_first=True,
    dtype=int
)

# --------------------------------------------------
# 9. Feature scaling
# --------------------------------------------------

scaler = StandardScaler()

data[["Age", "Fare"]] = scaler.fit_transform(
    data[["Age", "Fare"]]
)

# --------------------------------------------------
# 10. Display processed data
# --------------------------------------------------

print("\nProcessed Dataset:")
print(data.head())

print("\nFinal Shape:")
print(data.shape)

print("\nMissing Values After Preprocessing:")
print(data.isnull().sum())
# Out:
# Original Dataset
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...
